# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * After running all the analysis the conclusion was not a surprise - the weather becomes much warmer as we approache the equator.
#
# * There is no strong relationship between the latitude and cloudiness.
#
# * I have not discovered a strong relationship between latitude and wind speed. The strongest wind speed (approximately between 20 mph and 35 mph) sits somehwere between 60 and 70 latitude, however.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
#List for holding lat_lngs and cities
lat_lngs = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

cities = []
countries = []

# Identify nearest city for each lat, lng combination
for lat_lngs in lat_lngs:
    lat, lon = lat_lngs
    name = citipy.nearest_city(lat, lon).city_name
    country_code = citipy.nearest_city(lat, lon).country_code
    cities.append(name)
    countries.append(country_code)
cities_df = pd.DataFrame({"City": cities, "Country": countries})  

# Drop any duplicate values
cities_df = cities_df.drop_duplicates('City')

# Visualize the data frame
cities_df.head(2)
# Out:
#          City Country
# 0  abu samrah      qa
# 1    shenzhen      cn

# %%
# ~~~~~~~~~~~~~~~~~~~~~ METHOD 1 - DICTIONARY

# const_cities = {}
# # countries = {}

# url = "http://api.openweathermap.org/data/2.5/weather?"
# units = "metric"
# query_url = f"{url}appid={api_key}&units={units}&q="

# for city in cities[:50]:
#     response = requests.get(query_url + city).json()    
#     try:
#         const_cities[city] = response["name"]
#         const_cities[response["sys"]["country"]] = response["sys"]["country"]
#     except:
#         print("City not found. Skipping...")
#         continue

# %%
# # ~~~~~~~~~~~~~~~~~~~~~ METHOD 2 - LISTS

# cities_new = []
# countries_new = []
# lats = []

# url = "http://api.openweathermap.org/data/2.5/weather?"
# units = "metric"
# query_url = f"{url}appid={api_key}&units={units}&q="

# for city in cities[:50]:
#     response = requests.get(query_url + city).json()    
#     try:
#         cities_new.append(response["name"])
#         countries_new.append(response["sys"]["country"])
#         lats.append(response["coord"]["lat"])
# #     except Exception as e:
#     except:
# #         print(e)
#         print("Skipping...")
#         continue

# %%
# Creating a new DataFrame
cities_df["Date"] = ""
cities_df['Lat'] = ""
cities_df["Lng"] = ""
cities_df["Humidity"] = ""
cities_df["Wind Speed"] = ""
cities_df["Cloudiness"] = ""
cities_df["Max Temp"] = ""

cities_df.head(2)
# Out:
#          City Country Date Lat Lng Humidity Wind Speed Cloudiness Max Temp
# 0  abu samrah      qa
# 1    shenzhen      cn

# %%
# ~~~~~~~~~~~~~~~~~~~~~ METHOD 3 - DataFrame


row_count = 0

print("DATA RETRIEVAL")
print("~~~~~~~~~~~~~~~~~~~~~~~")

# Loop through the cities and perform API Calls
for index, row in cities_df.iterrows():
    target_url = "http://api.openweathermap.org/data/2.5/weather?q=%s&units=IMPERIAL&appid=%s" %(row["City"], api_key)
    response = requests.get(target_url).json()
    print("----------------------")
    print("Now retrieving city #%s: %s" % (row_count + 1, cities_df.loc[index]["City"]))
    print(target_url)
    row_count += 1
    
    try:     
        cities_df.set_value(index, "Lat", response["coord"]["lat"])
        cities_df.set_value(index, "Lng", response["coord"]["lon"])
        cities_df.set_value(index, "Date", response["dt"])
        cities_df.set_value(index, "Humidity", response["main"]["humidity"])
        cities_df.set_value(index, "Max Temp", response["main"]["temp_max"])
        cities_df.set_value(index, "Wind Speed", response["wind"]["speed"])
        cities_df.set_value(index, "Cloudiness", response["clouds"]["all"])
           
    except Exception as e:
        print(e)
        print("City not found. Skipping...")
        
    if row_count % 50 == 0:
        print("~~~~~~~~~~~~~~~~~~~~~~~~")
        print("PAUSE")
        time.sleep(30)
        
print("~~~~~~~~~~~~~~~~~~~~~~~~")
print("DATA RETRIEVAL COMPLETE")
# Out:
# DATA RETRIEVAL
# ~~~~~~~~~~~~~~~~~~~~~~~
# ----------------------
# Now retrieving city #1: abu samrah
# http://api.openweathermap.org/data/2.5/weather?q=abu samrah&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #2: shenzhen
# http://api.openweathermap.org/data/2.5/weather?q=shenzhen&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:16: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:17: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:21: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# ----------------------
# Now retrieving city #3: tuatapere
# http://api.openweathermap.org/data/2.5/weather?q=tuatapere&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #4: jamestown
# http://api.openweathermap.org/data/2.5/weather?q=jamestown&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #5: esperance
# http://api.openweathermap.org/data/2.5/weather?q=esperance&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #6: rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #7: taolanaro
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #8: busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #9: port alfred
# http://api.openweathermap.org/data/2.5/weather?q=port alfred&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #10: tondano
# http://api.openweathermap.org/data/2.5/weather?q=tondano&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #11: cherskiy
# http://api.openweathermap.org/data/2.5/weather?q=cherskiy&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #12: suntar
# http://api.openweathermap.org/data/2.5/weather?q=suntar&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #13: barentsburg
# http://api.openweathermap.org/data/2.5/weather?q=barentsburg&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #14: woodward
# http://api.openweathermap.org/data/2.5/weather?q=woodward&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #15: qaanaaq
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #16: paamiut
# http://api.openweathermap.org/data/2.5/weather?q=paamiut&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #17: jujuy
# http://api.openweathermap.org/data/2.5/weather?q=jujuy&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #18: nikolskoye
# http://api.openweathermap.org/data/2.5/weather?q=nikolskoye&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #19: georgetown
# http://api.openweathermap.org/data/2.5/weather?q=georgetown&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #20: mataura
# http://api.openweathermap.org/data/2.5/weather?q=mataura&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #21: hithadhoo
# http://api.openweathermap.org/data/2.5/weather?q=hithadhoo&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #22: lorengau
# http://api.openweathermap.org/data/2.5/weather?q=lorengau&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #23: marawi
# http://api.openweathermap.org/data/2.5/weather?q=marawi&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #24: tasiilaq
# http://api.openweathermap.org/data/2.5/weather?q=tasiilaq&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #25: bethel
# http://api.openweathermap.org/data/2.5/weather?q=bethel&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #26: yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #27: bosaso
# http://api.openweathermap.org/data/2.5/weather?q=bosaso&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #28: nikel
# http://api.openweathermap.org/data/2.5/weather?q=nikel&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #29: kodiak
# http://api.openweathermap.org/data/2.5/weather?q=kodiak&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #30: dikson
# http://api.openweathermap.org/data/2.5/weather?q=dikson&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #31: umzimvubu
# http://api.openweathermap.org/data/2.5/weather?q=umzimvubu&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #32: ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #33: puerto ayora
# http://api.openweathermap.org/data/2.5/weather?q=puerto ayora&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #34: tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #35: cape town
# http://api.openweathermap.org/data/2.5/weather?q=cape town&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #36: khatanga
# http://api.openweathermap.org/data/2.5/weather?q=khatanga&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #37: sorong
# http://api.openweathermap.org/data/2.5/weather?q=sorong&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #38: porosozero
# http://api.openweathermap.org/data/2.5/weather?q=porosozero&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #39: vaini
# http://api.openweathermap.org/data/2.5/weather?q=vaini&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #40: albany
# http://api.openweathermap.org/data/2.5/weather?q=albany&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #41: bluff
# http://api.openweathermap.org/data/2.5/weather?q=bluff&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #42: mahebourg
# http://api.openweathermap.org/data/2.5/weather?q=mahebourg&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #43: severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #44: vila velha
# http://api.openweathermap.org/data/2.5/weather?q=vila velha&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #45: punta arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta arenas&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #46: pevek
# http://api.openweathermap.org/data/2.5/weather?q=pevek&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #47: saint-philippe
# http://api.openweathermap.org/data/2.5/weather?q=saint-philippe&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #48: bandrele
# http://api.openweathermap.org/data/2.5/weather?q=bandrele&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #49: piopio
# http://api.openweathermap.org/data/2.5/weather?q=piopio&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #50: viedma
# http://api.openweathermap.org/data/2.5/weather?q=viedma&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ~~~~~~~~~~~~~~~~~~~~~~~~
# PAUSE
# ----------------------
# Now retrieving city #51: pita
# http://api.openweathermap.org/data/2.5/weather?q=pita&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #52: saint george
# http://api.openweathermap.org/data/2.5/weather?q=saint george&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #53: geraldton
# http://api.openweathermap.org/data/2.5/weather?q=geraldton&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #54: illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #55: hilo
# http://api.openweathermap.org/data/2.5/weather?q=hilo&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #56: guajara-mirim
# http://api.openweathermap.org/data/2.5/weather?q=guajara-mirim&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #57: padang
# http://api.openweathermap.org/data/2.5/weather?q=padang&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #58: bubaque
# http://api.openweathermap.org/data/2.5/weather?q=bubaque&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #59: copiapo
# http://api.openweathermap.org/data/2.5/weather?q=copiapo&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #60: lebu
# http://api.openweathermap.org/data/2.5/weather?q=lebu&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #61: cidreira
# http://api.openweathermap.org/data/2.5/weather?q=cidreira&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #62: te anau
# http://api.openweathermap.org/data/2.5/weather?q=te anau&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #63: carnarvon
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #64: isangel
# http://api.openweathermap.org/data/2.5/weather?q=isangel&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #65: xinpu
# http://api.openweathermap.org/data/2.5/weather?q=xinpu&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #66: ribeira grande
# http://api.openweathermap.org/data/2.5/weather?q=ribeira grande&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #67: atuona
# http://api.openweathermap.org/data/2.5/weather?q=atuona&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #68: chokurdakh
# http://api.openweathermap.org/data/2.5/weather?q=chokurdakh&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #69: airai
# http://api.openweathermap.org/data/2.5/weather?q=airai&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #70: kavaratti
# http://api.openweathermap.org/data/2.5/weather?q=kavaratti&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #71: lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?q=lazaro cardenas&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #72: souillac
# http://api.openweathermap.org/data/2.5/weather?q=souillac&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #73: yeletskiy
# http://api.openweathermap.org/data/2.5/weather?q=yeletskiy&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #74: faanui
# http://api.openweathermap.org/data/2.5/weather?q=faanui&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #75: broome
# http://api.openweathermap.org/data/2.5/weather?q=broome&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #76: goderich
# http://api.openweathermap.org/data/2.5/weather?q=goderich&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #77: bathsheba
# http://api.openweathermap.org/data/2.5/weather?q=bathsheba&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #78: grand river south east
# http://api.openweathermap.org/data/2.5/weather?q=grand river south east&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #79: sao miguel do araguaia
# http://api.openweathermap.org/data/2.5/weather?q=sao miguel do araguaia&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #80: pueblo nuevo
# http://api.openweathermap.org/data/2.5/weather?q=pueblo nuevo&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #81: atar
# http://api.openweathermap.org/data/2.5/weather?q=atar&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #82: somerset
# http://api.openweathermap.org/data/2.5/weather?q=somerset&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #83: boa vista
# http://api.openweathermap.org/data/2.5/weather?q=boa vista&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #84: sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?q=sentyabrskiy&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #85: hermanus
# http://api.openweathermap.org/data/2.5/weather?q=hermanus&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #86: oranjemund
# http://api.openweathermap.org/data/2.5/weather?q=oranjemund&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #87: kalemie
# http://api.openweathermap.org/data/2.5/weather?q=kalemie&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #88: college
# http://api.openweathermap.org/data/2.5/weather?q=college&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #89: inarcs
# http://api.openweathermap.org/data/2.5/weather?q=inarcs&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #90: catabola
# http://api.openweathermap.org/data/2.5/weather?q=catabola&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #91: kapaa
# http://api.openweathermap.org/data/2.5/weather?q=kapaa&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #92: araouane
# http://api.openweathermap.org/data/2.5/weather?q=araouane&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #93: tura
# http://api.openweathermap.org/data/2.5/weather?q=tura&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #94: laguna
# http://api.openweathermap.org/data/2.5/weather?q=laguna&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #95: mehamn
# http://api.openweathermap.org/data/2.5/weather?q=mehamn&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #96: alberton
# http://api.openweathermap.org/data/2.5/weather?q=alberton&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #97: san juan
# http://api.openweathermap.org/data/2.5/weather?q=san juan&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #98: amderma
# http://api.openweathermap.org/data/2.5/weather?q=amderma&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #99: miami beach
# http://api.openweathermap.org/data/2.5/weather?q=miami beach&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #100: aklavik
# http://api.openweathermap.org/data/2.5/weather?q=aklavik&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ~~~~~~~~~~~~~~~~~~~~~~~~
# PAUSE
# ----------------------
# Now retrieving city #101: provideniya
# http://api.openweathermap.org/data/2.5/weather?q=provideniya&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #102: ardakan
# http://api.openweathermap.org/data/2.5/weather?q=ardakan&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #103: beloha
# http://api.openweathermap.org/data/2.5/weather?q=beloha&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #104: wajir
# http://api.openweathermap.org/data/2.5/weather?q=wajir&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #105: hobart
# http://api.openweathermap.org/data/2.5/weather?q=hobart&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #106: dunedin
# http://api.openweathermap.org/data/2.5/weather?q=dunedin&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #107: kuznechnoye
# http://api.openweathermap.org/data/2.5/weather?q=kuznechnoye&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #108: lompoc
# http://api.openweathermap.org/data/2.5/weather?q=lompoc&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #109: lukovetskiy
# http://api.openweathermap.org/data/2.5/weather?q=lukovetskiy&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #110: kushiro
# http://api.openweathermap.org/data/2.5/weather?q=kushiro&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #111: nenjiang
# http://api.openweathermap.org/data/2.5/weather?q=nenjiang&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #112: chuy
# http://api.openweathermap.org/data/2.5/weather?q=chuy&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #113: bengkulu
# http://api.openweathermap.org/data/2.5/weather?q=bengkulu&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #114: vao
# http://api.openweathermap.org/data/2.5/weather?q=vao&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #115: guerrero negro
# http://api.openweathermap.org/data/2.5/weather?q=guerrero negro&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #116: fairbanks
# http://api.openweathermap.org/data/2.5/weather?q=fairbanks&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #117: tahoua
# http://api.openweathermap.org/data/2.5/weather?q=tahoua&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #118: umm lajj
# http://api.openweathermap.org/data/2.5/weather?q=umm lajj&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #119: east london
# http://api.openweathermap.org/data/2.5/weather?q=east london&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #120: kabompo
# http://api.openweathermap.org/data/2.5/weather?q=kabompo&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #121: port elizabeth
# http://api.openweathermap.org/data/2.5/weather?q=port elizabeth&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #122: seymchan
# http://api.openweathermap.org/data/2.5/weather?q=seymchan&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #123: chifeng
# http://api.openweathermap.org/data/2.5/weather?q=chifeng&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #124: huarmey
# http://api.openweathermap.org/data/2.5/weather?q=huarmey&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #125: beringovskiy
# http://api.openweathermap.org/data/2.5/weather?q=beringovskiy&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #126: ust-kuyga
# http://api.openweathermap.org/data/2.5/weather?q=ust-kuyga&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #127: ilulissat
# http://api.openweathermap.org/data/2.5/weather?q=ilulissat&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #128: ternate
# http://api.openweathermap.org/data/2.5/weather?q=ternate&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #129: namibe
# http://api.openweathermap.org/data/2.5/weather?q=namibe&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #130: barrow
# http://api.openweathermap.org/data/2.5/weather?q=barrow&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #131: bitung
# http://api.openweathermap.org/data/2.5/weather?q=bitung&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #132: arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?q=arraial do cabo&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #133: hobyo
# http://api.openweathermap.org/data/2.5/weather?q=hobyo&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #134: jalu
# http://api.openweathermap.org/data/2.5/weather?q=jalu&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #135: tabuk
# http://api.openweathermap.org/data/2.5/weather?q=tabuk&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #136: northam
# http://api.openweathermap.org/data/2.5/weather?q=northam&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #137: caravelas
# http://api.openweathermap.org/data/2.5/weather?q=caravelas&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #138: new norfolk
# http://api.openweathermap.org/data/2.5/weather?q=new norfolk&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #139: clyde river
# http://api.openweathermap.org/data/2.5/weather?q=clyde river&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #140: vestmanna
# http://api.openweathermap.org/data/2.5/weather?q=vestmanna&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #141: tilichiki
# http://api.openweathermap.org/data/2.5/weather?q=tilichiki&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #142: san mateo del mar
# http://api.openweathermap.org/data/2.5/weather?q=san mateo del mar&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #143: cojumatlan
# http://api.openweathermap.org/data/2.5/weather?q=cojumatlan&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #144: morehead
# http://api.openweathermap.org/data/2.5/weather?q=morehead&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #145: butaritari
# http://api.openweathermap.org/data/2.5/weather?q=butaritari&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #146: sampit
# http://api.openweathermap.org/data/2.5/weather?q=sampit&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #147: leningradskiy
# http://api.openweathermap.org/data/2.5/weather?q=leningradskiy&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #148: mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?q=mitsamiouli&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #149: xingyi
# http://api.openweathermap.org/data/2.5/weather?q=xingyi&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #150: saldanha
# http://api.openweathermap.org/data/2.5/weather?q=saldanha&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ~~~~~~~~~~~~~~~~~~~~~~~~
# PAUSE
# ----------------------
# Now retrieving city #151: calais
# http://api.openweathermap.org/data/2.5/weather?q=calais&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #152: klaksvik
# http://api.openweathermap.org/data/2.5/weather?q=klaksvik&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #153: eunice
# http://api.openweathermap.org/data/2.5/weather?q=eunice&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #154: eenhana
# http://api.openweathermap.org/data/2.5/weather?q=eenhana&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #155: nicoya
# http://api.openweathermap.org/data/2.5/weather?q=nicoya&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #156: touros
# http://api.openweathermap.org/data/2.5/weather?q=touros&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #157: malumfashi
# http://api.openweathermap.org/data/2.5/weather?q=malumfashi&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #158: tual
# http://api.openweathermap.org/data/2.5/weather?q=tual&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #159: upernavik
# http://api.openweathermap.org/data/2.5/weather?q=upernavik&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #160: saskylakh
# http://api.openweathermap.org/data/2.5/weather?q=saskylakh&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #161: ancud
# http://api.openweathermap.org/data/2.5/weather?q=ancud&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #162: eldorado
# http://api.openweathermap.org/data/2.5/weather?q=eldorado&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #163: morada nova
# http://api.openweathermap.org/data/2.5/weather?q=morada nova&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #164: luganville
# http://api.openweathermap.org/data/2.5/weather?q=luganville&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #165: saleaula
# http://api.openweathermap.org/data/2.5/weather?q=saleaula&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #166: lasa
# http://api.openweathermap.org/data/2.5/weather?q=lasa&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #167: san patricio
# http://api.openweathermap.org/data/2.5/weather?q=san patricio&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #168: saint-francois
# http://api.openweathermap.org/data/2.5/weather?q=saint-francois&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #169: nalut
# http://api.openweathermap.org/data/2.5/weather?q=nalut&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #170: igrim
# http://api.openweathermap.org/data/2.5/weather?q=igrim&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #171: polis
# http://api.openweathermap.org/data/2.5/weather?q=polis&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #172: rypefjord
# http://api.openweathermap.org/data/2.5/weather?q=rypefjord&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #173: ferrol
# http://api.openweathermap.org/data/2.5/weather?q=ferrol&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #174: pisco
# http://api.openweathermap.org/data/2.5/weather?q=pisco&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #175: kapuskasing
# http://api.openweathermap.org/data/2.5/weather?q=kapuskasing&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #176: thompson
# http://api.openweathermap.org/data/2.5/weather?q=thompson&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #177: tamandare
# http://api.openweathermap.org/data/2.5/weather?q=tamandare&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #178: kaitangata
# http://api.openweathermap.org/data/2.5/weather?q=kaitangata&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #179: busing
# http://api.openweathermap.org/data/2.5/weather?q=busing&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #180: baoying
# http://api.openweathermap.org/data/2.5/weather?q=baoying&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #181: medzilaborce
# http://api.openweathermap.org/data/2.5/weather?q=medzilaborce&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #182: komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?q=komsomolskiy&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #183: mizdah
# http://api.openweathermap.org/data/2.5/weather?q=mizdah&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #184: sitka
# http://api.openweathermap.org/data/2.5/weather?q=sitka&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #185: tambul
# http://api.openweathermap.org/data/2.5/weather?q=tambul&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #186: itoman
# http://api.openweathermap.org/data/2.5/weather?q=itoman&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #187: palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?q=palabuhanratu&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #188: tsihombe
# http://api.openweathermap.org/data/2.5/weather?q=tsihombe&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #189: koungou
# http://api.openweathermap.org/data/2.5/weather?q=koungou&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #190: meulaboh
# http://api.openweathermap.org/data/2.5/weather?q=meulaboh&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #191: houston
# http://api.openweathermap.org/data/2.5/weather?q=houston&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #192: mar del plata
# http://api.openweathermap.org/data/2.5/weather?q=mar del plata&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #193: diffa
# http://api.openweathermap.org/data/2.5/weather?q=diffa&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #194: hilsa
# http://api.openweathermap.org/data/2.5/weather?q=hilsa&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #195: eureka
# http://api.openweathermap.org/data/2.5/weather?q=eureka&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #196: great bend
# http://api.openweathermap.org/data/2.5/weather?q=great bend&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #197: kanye
# http://api.openweathermap.org/data/2.5/weather?q=kanye&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #198: kasempa
# http://api.openweathermap.org/data/2.5/weather?q=kasempa&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #199: palmer
# http://api.openweathermap.org/data/2.5/weather?q=palmer&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #200: dali
# http://api.openweathermap.org/data/2.5/weather?q=dali&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ~~~~~~~~~~~~~~~~~~~~~~~~
# PAUSE
# ----------------------
# Now retrieving city #201: bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #202: san ramon
# http://api.openweathermap.org/data/2.5/weather?q=san ramon&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #203: thinadhoo
# http://api.openweathermap.org/data/2.5/weather?q=thinadhoo&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #204: katsuura
# http://api.openweathermap.org/data/2.5/weather?q=katsuura&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #205: saint anthony
# http://api.openweathermap.org/data/2.5/weather?q=saint anthony&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #206: shenjiamen
# http://api.openweathermap.org/data/2.5/weather?q=shenjiamen&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #207: kochinda
# http://api.openweathermap.org/data/2.5/weather?q=kochinda&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #208: okhotsk
# http://api.openweathermap.org/data/2.5/weather?q=okhotsk&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #209: sao gabriel da cachoeira
# http://api.openweathermap.org/data/2.5/weather?q=sao gabriel da cachoeira&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #210: villa bruzual
# http://api.openweathermap.org/data/2.5/weather?q=villa bruzual&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #211: tabiauea
# http://api.openweathermap.org/data/2.5/weather?q=tabiauea&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #212: canto do buriti
# http://api.openweathermap.org/data/2.5/weather?q=canto do buriti&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #213: quiindy
# http://api.openweathermap.org/data/2.5/weather?q=quiindy&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #214: portland
# http://api.openweathermap.org/data/2.5/weather?q=portland&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #215: cairns
# http://api.openweathermap.org/data/2.5/weather?q=cairns&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #216: mollendo
# http://api.openweathermap.org/data/2.5/weather?q=mollendo&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #217: morant bay
# http://api.openweathermap.org/data/2.5/weather?q=morant bay&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #218: columbus
# http://api.openweathermap.org/data/2.5/weather?q=columbus&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #219: lakselv
# http://api.openweathermap.org/data/2.5/weather?q=lakselv&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #220: mulchen
# http://api.openweathermap.org/data/2.5/weather?q=mulchen&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #221: belushya guba
# http://api.openweathermap.org/data/2.5/weather?q=belushya guba&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #222: ponta do sol
# http://api.openweathermap.org/data/2.5/weather?q=ponta do sol&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #223: samusu
# http://api.openweathermap.org/data/2.5/weather?q=samusu&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #224: saint-georges
# http://api.openweathermap.org/data/2.5/weather?q=saint-georges&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #225: henties bay
# http://api.openweathermap.org/data/2.5/weather?q=henties bay&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #226: nuuk
# http://api.openweathermap.org/data/2.5/weather?q=nuuk&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #227: orlovskiy
# http://api.openweathermap.org/data/2.5/weather?q=orlovskiy&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #228: los ranchos de albuquerque
# http://api.openweathermap.org/data/2.5/weather?q=los ranchos de albuquerque&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #229: belchatow
# http://api.openweathermap.org/data/2.5/weather?q=belchatow&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #230: bolungarvik
# http://api.openweathermap.org/data/2.5/weather?q=bolungarvik&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #231: akdepe
# http://api.openweathermap.org/data/2.5/weather?q=akdepe&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #232: baruun-urt
# http://api.openweathermap.org/data/2.5/weather?q=baruun-urt&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #233: kailua
# http://api.openweathermap.org/data/2.5/weather?q=kailua&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #234: hasaki
# http://api.openweathermap.org/data/2.5/weather?q=hasaki&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #235: raudeberg
# http://api.openweathermap.org/data/2.5/weather?q=raudeberg&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #236: narsaq
# http://api.openweathermap.org/data/2.5/weather?q=narsaq&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #237: hay river
# http://api.openweathermap.org/data/2.5/weather?q=hay river&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #238: juegang
# http://api.openweathermap.org/data/2.5/weather?q=juegang&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #239: manicore
# http://api.openweathermap.org/data/2.5/weather?q=manicore&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #240: san isidro
# http://api.openweathermap.org/data/2.5/weather?q=san isidro&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #241: road town
# http://api.openweathermap.org/data/2.5/weather?q=road town&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #242: ewa beach
# http://api.openweathermap.org/data/2.5/weather?q=ewa beach&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #243: tessalit
# http://api.openweathermap.org/data/2.5/weather?q=tessalit&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #244: zhanakorgan
# http://api.openweathermap.org/data/2.5/weather?q=zhanakorgan&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #245: bintulu
# http://api.openweathermap.org/data/2.5/weather?q=bintulu&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #246: noumea
# http://api.openweathermap.org/data/2.5/weather?q=noumea&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #247: sinnamary
# http://api.openweathermap.org/data/2.5/weather?q=sinnamary&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #248: kushmurun
# http://api.openweathermap.org/data/2.5/weather?q=kushmurun&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #249: tahta
# http://api.openweathermap.org/data/2.5/weather?q=tahta&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #250: pitimbu
# http://api.openweathermap.org/data/2.5/weather?q=pitimbu&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ~~~~~~~~~~~~~~~~~~~~~~~~
# PAUSE
# ----------------------
# Now retrieving city #251: rio gallegos
# http://api.openweathermap.org/data/2.5/weather?q=rio gallegos&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #252: kaduqli
# http://api.openweathermap.org/data/2.5/weather?q=kaduqli&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #253: fayaoue
# http://api.openweathermap.org/data/2.5/weather?q=fayaoue&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #254: sogne
# http://api.openweathermap.org/data/2.5/weather?q=sogne&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #255: dien bien
# http://api.openweathermap.org/data/2.5/weather?q=dien bien&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #256: kirakira
# http://api.openweathermap.org/data/2.5/weather?q=kirakira&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #257: wakkanai
# http://api.openweathermap.org/data/2.5/weather?q=wakkanai&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #258: hanmer springs
# http://api.openweathermap.org/data/2.5/weather?q=hanmer springs&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #259: ayaviri
# http://api.openweathermap.org/data/2.5/weather?q=ayaviri&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #260: gagarin
# http://api.openweathermap.org/data/2.5/weather?q=gagarin&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #261: kapit
# http://api.openweathermap.org/data/2.5/weather?q=kapit&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #262: korla
# http://api.openweathermap.org/data/2.5/weather?q=korla&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #263: buala
# http://api.openweathermap.org/data/2.5/weather?q=buala&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #264: nguiu
# http://api.openweathermap.org/data/2.5/weather?q=nguiu&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #265: tsabong
# http://api.openweathermap.org/data/2.5/weather?q=tsabong&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #266: kyzyl-suu
# http://api.openweathermap.org/data/2.5/weather?q=kyzyl-suu&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #267: dawei
# ...
# ----------------------
# Now retrieving city #517: kasungu
# http://api.openweathermap.org/data/2.5/weather?q=kasungu&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #518: alice
# http://api.openweathermap.org/data/2.5/weather?q=alice&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #519: bahia de caraquez
# http://api.openweathermap.org/data/2.5/weather?q=bahia de caraquez&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #520: kavieng
# http://api.openweathermap.org/data/2.5/weather?q=kavieng&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #521: zhigansk
# http://api.openweathermap.org/data/2.5/weather?q=zhigansk&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #522: lucea
# http://api.openweathermap.org/data/2.5/weather?q=lucea&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #523: hue
# http://api.openweathermap.org/data/2.5/weather?q=hue&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #524: fukue
# http://api.openweathermap.org/data/2.5/weather?q=fukue&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #525: price
# http://api.openweathermap.org/data/2.5/weather?q=price&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #526: sankt florian
# http://api.openweathermap.org/data/2.5/weather?q=sankt florian&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #527: grand centre
# http://api.openweathermap.org/data/2.5/weather?q=grand centre&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #528: anamur
# http://api.openweathermap.org/data/2.5/weather?q=anamur&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #529: iqaluit
# http://api.openweathermap.org/data/2.5/weather?q=iqaluit&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #530: bataipora
# http://api.openweathermap.org/data/2.5/weather?q=bataipora&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #531: eydhafushi
# http://api.openweathermap.org/data/2.5/weather?q=eydhafushi&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #532: anloga
# http://api.openweathermap.org/data/2.5/weather?q=anloga&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #533: vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?q=vila franca do campo&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #534: kamenskoye
# http://api.openweathermap.org/data/2.5/weather?q=kamenskoye&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #535: wulanhaote
# http://api.openweathermap.org/data/2.5/weather?q=wulanhaote&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #536: puri
# http://api.openweathermap.org/data/2.5/weather?q=puri&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #537: porto-vecchio
# http://api.openweathermap.org/data/2.5/weather?q=porto-vecchio&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #538: kultuk
# http://api.openweathermap.org/data/2.5/weather?q=kultuk&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #539: myskhako
# http://api.openweathermap.org/data/2.5/weather?q=myskhako&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #540: daura
# http://api.openweathermap.org/data/2.5/weather?q=daura&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #541: codajas
# http://api.openweathermap.org/data/2.5/weather?q=codajas&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #542: christchurch
# http://api.openweathermap.org/data/2.5/weather?q=christchurch&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #543: taltal
# http://api.openweathermap.org/data/2.5/weather?q=taltal&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #544: avera
# http://api.openweathermap.org/data/2.5/weather?q=avera&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #545: shelburne
# http://api.openweathermap.org/data/2.5/weather?q=shelburne&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #546: kemijarvi
# http://api.openweathermap.org/data/2.5/weather?q=kemijarvi&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #547: necochea
# http://api.openweathermap.org/data/2.5/weather?q=necochea&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #548: san luis
# http://api.openweathermap.org/data/2.5/weather?q=san luis&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #549: ndioum
# http://api.openweathermap.org/data/2.5/weather?q=ndioum&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #550: tuggurt
# http://api.openweathermap.org/data/2.5/weather?q=tuggurt&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ~~~~~~~~~~~~~~~~~~~~~~~~
# PAUSE
# ----------------------
# Now retrieving city #551: barrhead
# http://api.openweathermap.org/data/2.5/weather?q=barrhead&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #552: yichun
# http://api.openweathermap.org/data/2.5/weather?q=yichun&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #553: oktyabrskiy
# http://api.openweathermap.org/data/2.5/weather?q=oktyabrskiy&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #554: pangnirtung
# http://api.openweathermap.org/data/2.5/weather?q=pangnirtung&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #555: barinas
# http://api.openweathermap.org/data/2.5/weather?q=barinas&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #556: beisfjord
# http://api.openweathermap.org/data/2.5/weather?q=beisfjord&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #557: atherton
# http://api.openweathermap.org/data/2.5/weather?q=atherton&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #558: poronaysk
# http://api.openweathermap.org/data/2.5/weather?q=poronaysk&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #559: atasu
# http://api.openweathermap.org/data/2.5/weather?q=atasu&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #560: opuwo
# http://api.openweathermap.org/data/2.5/weather?q=opuwo&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #561: elizabeth city
# http://api.openweathermap.org/data/2.5/weather?q=elizabeth city&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #562: guangyuan
# http://api.openweathermap.org/data/2.5/weather?q=guangyuan&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #563: sarkand
# http://api.openweathermap.org/data/2.5/weather?q=sarkand&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #564: grootfontein
# http://api.openweathermap.org/data/2.5/weather?q=grootfontein&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #565: jumla
# http://api.openweathermap.org/data/2.5/weather?q=jumla&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #566: praya
# http://api.openweathermap.org/data/2.5/weather?q=praya&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #567: guadalupe y calvo
# http://api.openweathermap.org/data/2.5/weather?q=guadalupe y calvo&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #568: mackenzie
# http://api.openweathermap.org/data/2.5/weather?q=mackenzie&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #569: verkhnyaya inta
# http://api.openweathermap.org/data/2.5/weather?q=verkhnyaya inta&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #570: east wenatchee
# http://api.openweathermap.org/data/2.5/weather?q=east wenatchee&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #571: hihifo
# http://api.openweathermap.org/data/2.5/weather?q=hihifo&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# 'coord'
# City not found. Skipping...
# ----------------------
# Now retrieving city #572: labuhan
# http://api.openweathermap.org/data/2.5/weather?q=labuhan&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #573: pointe michel
# http://api.openweathermap.org/data/2.5/weather?q=pointe michel&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #574: barmer
# http://api.openweathermap.org/data/2.5/weather?q=barmer&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #575: aasiaat
# http://api.openweathermap.org/data/2.5/weather?q=aasiaat&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #576: caucaia
# http://api.openweathermap.org/data/2.5/weather?q=caucaia&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #577: ratnagiri
# http://api.openweathermap.org/data/2.5/weather?q=ratnagiri&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #578: samarai
# http://api.openweathermap.org/data/2.5/weather?q=samarai&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #579: bilibino
# http://api.openweathermap.org/data/2.5/weather?q=bilibino&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #580: luanda
# http://api.openweathermap.org/data/2.5/weather?q=luanda&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #581: alofi
# http://api.openweathermap.org/data/2.5/weather?q=alofi&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #582: aripuana
# http://api.openweathermap.org/data/2.5/weather?q=aripuana&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #583: toguchin
# http://api.openweathermap.org/data/2.5/weather?q=toguchin&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #584: dongsheng
# http://api.openweathermap.org/data/2.5/weather?q=dongsheng&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #585: abu dhabi
# http://api.openweathermap.org/data/2.5/weather?q=abu dhabi&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #586: salinopolis
# http://api.openweathermap.org/data/2.5/weather?q=salinopolis&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #587: baneh
# http://api.openweathermap.org/data/2.5/weather?q=baneh&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #588: elat
# http://api.openweathermap.org/data/2.5/weather?q=elat&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #589: los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?q=los llanos de aridane&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #590: juliaca
# http://api.openweathermap.org/data/2.5/weather?q=juliaca&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #591: diyarb najm
# http://api.openweathermap.org/data/2.5/weather?q=diyarb najm&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #592: perama
# http://api.openweathermap.org/data/2.5/weather?q=perama&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #593: nykoping
# http://api.openweathermap.org/data/2.5/weather?q=nykoping&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #594: atbasar
# http://api.openweathermap.org/data/2.5/weather?q=atbasar&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #595: zalantun
# http://api.openweathermap.org/data/2.5/weather?q=zalantun&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #596: khorramshahr
# http://api.openweathermap.org/data/2.5/weather?q=khorramshahr&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #597: ahipara
# http://api.openweathermap.org/data/2.5/weather?q=ahipara&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #598: pittsfield
# http://api.openweathermap.org/data/2.5/weather?q=pittsfield&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #599: clearwater
# http://api.openweathermap.org/data/2.5/weather?q=clearwater&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #600: valle hermoso
# http://api.openweathermap.org/data/2.5/weather?q=valle hermoso&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ~~~~~~~~~~~~~~~~~~~~~~~~
# PAUSE
# ----------------------
# Now retrieving city #601: hot springs
# http://api.openweathermap.org/data/2.5/weather?q=hot springs&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #602: presidencia roque saenz pena
# http://api.openweathermap.org/data/2.5/weather?q=presidencia roque saenz pena&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #603: sotnikovo
# http://api.openweathermap.org/data/2.5/weather?q=sotnikovo&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #604: mantua
# http://api.openweathermap.org/data/2.5/weather?q=mantua&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #605: erenhot
# http://api.openweathermap.org/data/2.5/weather?q=erenhot&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #606: camacha
# http://api.openweathermap.org/data/2.5/weather?q=camacha&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ----------------------
# Now retrieving city #607: slobodskoy
# http://api.openweathermap.org/data/2.5/weather?q=slobodskoy&units=IMPERIAL&appid=b6efcd0fa8c7d0e32275b8ea3b5a53e3
# ~~~~~~~~~~~~~~~~~~~~~~~~
# DATA RETRIEVAL COMPLETE

# %%
cities_df.head(2)
# Out:
#          City Country        Date    Lat     Lng Humidity Wind Speed  \
# 0  abu samrah      qa  1553969087   35.3   37.18       96       3.06
# 1    shenzhen      cn  1553969000  22.54  114.05       83      13.87
#
#   Cloudiness Max Temp
# 0         88    51.42
# 1         40     73.4

# %%
# Replace empty rows with NuN
cities_df['Date'].replace('', np.nan, inplace=True)
cities_df['Lat'].replace('', np.nan, inplace=True)
cities_df['Lng'].replace('', np.nan, inplace=True)
cities_df['Humidity'].replace('', np.nan, inplace=True)
cities_df['Wind Speed'].replace('', np.nan, inplace=True)
cities_df['Cloudiness'].replace('', np.nan, inplace=True)
cities_df['Max Temp'].replace('', np.nan, inplace=True)

cities_df.head(2)
# Out:
#          City Country          Date    Lat     Lng  Humidity  Wind Speed  \
# 0  abu samrah      qa  1.553969e+09  35.30   37.18      96.0        3.06
# 1    shenzhen      cn  1.553969e+09  22.54  114.05      83.0       13.87
#
#    Cloudiness  Max Temp
# 0        88.0     51.42
# 1        40.0     73.40

# %%
# Dropn NaN Rows
clean_cities_df = cities_df.dropna()
clean_cities_df.head(2)
# Out:
#          City Country          Date    Lat     Lng  Humidity  Wind Speed  \
# 0  abu samrah      qa  1.553969e+09  35.30   37.18      96.0        3.06
# 1    shenzhen      cn  1.553969e+09  22.54  114.05      83.0       13.87
#
#    Cloudiness  Max Temp
# 0        88.0     51.42
# 1        40.0     73.40

# %%
# clean_cities_df['Date'] = clean_cities_df['Date'].astype('datetime64[ns]')
# clean_cities_df
clean_cities_df['Date'] = pd.to_datetime(clean_cities_df['Date'], unit='s')
clean_cities_df.head(2)
# Out:
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#          City Country                Date    Lat     Lng  Humidity  \
# 0  abu samrah      qa 2019-03-30 18:04:47  35.30   37.18      96.0
# 1    shenzhen      cn 2019-03-30 18:03:20  22.54  114.05      83.0
#
#    Wind Speed  Cloudiness  Max Temp
# 0        3.06        88.0     51.42
# 1       13.87        40.0     73.40

# %%
# converting DataFrame to csv
clean_cities_df.to_csv("clean_cities.csv", index=False, header=True)

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
ax1 = cities_df.plot.scatter(x='Lat',
                       y='Max Temp',
                       facecolors="blue", marker="o", edgecolors="black", alpha=1)
plt.title("City Latitude vs. Max Temperature (03/26/2019)")
plt.xlabel("City Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()

# %%
# Save picture
plt.savefig('City Latitude vs. Max Temperature.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
ax2 = clean_cities_df.plot.scatter(x='Lat',
                       y='Humidity',
                       facecolors="blue", marker="o", edgecolors="black", alpha=1)
plt.title("City Latitude vs. Humidity (03/26/2019)")
plt.xlabel("City Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(0, 105)
plt.grid()

# %%
# Save picture
plt.savefig('City Latitude vs. Humidity.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
ax3 = clean_cities_df.plot.scatter(x='Lat',
                       y='Cloudiness',
                       facecolors="blue", marker="o", edgecolors="black", alpha=1)
plt.title("City Latitude vs. Cloudiness (03/26/2019)")
plt.xlabel("City Latitude")
plt.ylabel("Cloudiness (%)")
plt.ylim(0, 105)
plt.grid()

# %%
# Save picture
plt.savefig('City Latitude vs. Cloudiness.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
ax4 = clean_cities_df.plot.scatter(x='Lat',
                       y='Wind Speed',
                       facecolors="blue", marker="o", edgecolors="black", alpha=1)
plt.title("City Latitude vs. Wind Speed (03/26/2019)")
plt.xlabel("City Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(0, 105)
plt.grid()

# %%
# Save picture
plt.savefig('City Latitude vs. Wind Speed.png')
